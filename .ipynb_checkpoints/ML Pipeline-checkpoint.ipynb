# %% [markdown]
# ## Importing Tools

# %%
import pandas            as pd
import numpy             as np
import seaborn           as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## EDA

# %% [markdown]
# * ### Imputing

# %%
# See percentage of missing data
df.isnull().sum()/len(df)

# %%
# Label Enconder - for binary

#Import LabelEnconder
from sklearn.preprocessing import LabelEnconder

#Create a LabelEnconder object
le = LabelEnconder()

#Encode a categorical feature
df['cat_encoded'] = le.fit_transfomr(df.cat)

# %%
# One Hot Encoding - creates collumns

#Create One-Hot encoded features
ohe = pd.get_dummies(df.cat, prefix = 'ohe_cat')

#Drop the initial feature
df.drop('cat', axis = 1, inplace = True)

#Comcatenate OHE features to the dataframe
df = pd.concat([df,ohe], axis = 1)

# %%
# Imputes constant value - could use 'most_frequent'

# Import SimpleImputer
from sklearn.impute import SimpleImputer

# Create constant imputer
constant_imputer = SimpleImputer(strategy= 'constant', fill_value='MISS')

# building_id imputation
rental_listings[['building_id']] = constant_imputer.fit_transform(rental_listings[['building_id']])

# %%
# Imputes mean value - could also use median

# Import SimpleImputer
from sklearn.impute import SimpleImputer

# Create constant imputer
mean_imputer = SimpleImputer(strategy= 'mean', fill_value='MISS')

# building_id imputation
rental_listings[['building_id']] = mean_imputer.fit_transform(rental_listings[['building_id']])

# %% [markdown]
# * ### Target Encoding

# %%
def mean_target_encoding(train, test, target, categorical, alpha=5):
  
    # Get the train feature
    train_feature = train_mean_target_encoding(train, target, categorical, alpha)
  
    # Get the test feature
    test_feature = test_mean_target_encoding(train, test, target, categorical, alpha)
    
    # Return new features to add to the model
    return train_feature, test_feature

# %%
# Create 5-fold cross-validation
kf = KFold(n_splits=5, random_state=123, shuffle=True)

# For each folds split
for train_index, test_index in kf.split(bryant_shots):
    cv_train, cv_test = bryant_shots.iloc[train_index], bryant_shots.iloc[test_index]

    # Create mean target encoded feature
    cv_train['game_id_enc'], cv_test['game_id_enc'] = mean_target_encoding(train=cv_train,
                                                                           test= cv_test,
                                                                           target='shot_made_flag',
                                                                           categorical='game_id',
                                                                           alpha=5)
    # Look at the encoding
    print(cv_train[['game_id', 'shot_made_flag', 'game_id_enc']].sample(n=1))

# %% [markdown]
# * ### Data Properties

# %%
# Shapes of train and test data (columns x rows)
print('Train shape:', train.shape)
print('Test shape:', test.shape)

# Describe the target variable (data statistics)
print(train.describe())

# Train distribution of passengers within rides
# counts the numbber of appereances of each value
print(train.passenger_count.value_counts())

# %%
# Find the median price by the interest level
prices = train.groupby('interest_level', as_index = False)['price'].median()

# %% [markdown]
# * ### Features

# %% [markdown]
# Utilizar [coeficientes](https://operdata.com.br/blog/coeficientes-de-correlacao/) para descobrir a relação entre as features e o target e plotar o gráfico.

# %%
# Concatenar treino e teste quando criando features
data = pd.concat([train, test])

# Separar na hora de treinar
train = data[data.id.isin(train.id)]
test = data[data.id.isin(test.id)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for col in colunas:
    print( ' %16s   %12.4f   %9.4f' % (col, 
                                       pearsonr(dados[col],dados['preco'])[0], 
                                       pearsonr(dados[col],dados['preco'])[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-462bb2e6ff31> in <module>
# ----> 1 for col in colunas:
#       2     print( ' %16s   %12.4f   %9.4f' % (col,
#       3                                        pearsonr(dados[col],dados['preco'])[0],
#       4                                        pearsonr(dados[col],dados['preco'])[1]))
#
# NameError: name 'colunas' is not defined

# %% [markdown]
# ## Scoring

# %%
# For each of 3 trained models
for model in [xg_depth_2, xg_depth_8, xg_depth_15]:
    # Make predictions
    train_pred = model.predict(dtrain)     
    test_pred = model.predict(dtest)          
    
    # Calculate metrics
    mse_train = mean_squared_error(train['sales'], train_pred)                  
    mse_test = mean_squared_error(test['sales'], test_pred)
    print('MSE Train: {:.3f}. MSE Test: {:.3f}'.format(mse_train, mse_test))

# %%
# Import StratifiedKFold
from sklearn.model_selection import StratifiedKFold

# Create a StratifiedKFold object
str_kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=123)

# Loop through each split
fold = 0
for train_index, test_index in str_kf.split(train, train['interest_level']):
    # Obtain training and testing folds
    cv_train, cv_test = train.iloc[train_index], train.iloc[test_index]
    print('Fold: {}'.format(fold))
    print('CV train shape: {}'.format(cv_train.shape))
    print('Medium interest listings in CV train: {}\n'.format(sum(cv_train.interest_level == 'medium')))
    fold += 1

# %% [markdown]
# * ### Validation Pipeline

# %%
fold_metrics = []

for train_index, test_index in str_kf.split(train):
    cv_train, cv_test = train.iloc[train_index], train.iloc[test_index]
    # Train Model
    model.fit(cv_train)
    # Make predictions
    predictions = model.predict(cv_test)
    # Calculate the metric
    metric = evaluate(cv_test, predictions)
    fold_metrics.append(metric)
    
# Overall Validation Score
overall_score_minimizing = np.mean(fold_metrics) + np.std(fold_metrics)
